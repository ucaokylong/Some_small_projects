# %% [markdown]
# <a href="https://colab.research.google.com/github/ucaokylong/Some_small_projects/blob/main/project_stock_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **0. Tải bộ dữ liệu**
# **Lưu ý:** Nếu không thể tải bằng gdown do bị giới hạn số lượt tải, các bạn hãy tải thủ công và đưa lên drive của mình, sau đó copy từ drive vào colab.
# ```python
# from google.colab import drive
#
# drive.mount('/content/drive')
# !cp /path/to/dataset/on/your/drive .
# ```

# %%
pip install --upgrade gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.7.3)
# Collecting gdown
#   Downloading gdown-5.1.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.7.3
#     Uninstalling gdown-4.7.3:
#       Successfully uninstalled gdown-4.7.3
# Successfully installed gdown-5.1.0

# %%
# https://drive.google.com/file/d/1FC2P-NC8q_6cAqYIAkV4mBH5MCF1c-oc/view?usp=share_link
# !gdown 1FC2P-NC8q_6cAqYIAkV4mBH5MCF1c-oc
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1FC2P-NC8q_6cAqYIAkV4mBH5MCF1c-oc
# To: /content/tesla_stock_price.zip
# 100% 34.1k/34.1k [00:00<00:00, 90.2MB/s]

# %%
# !unzip './tesla_stock_price.zip'
# Out:
# Archive:  ./tesla_stock_price.zip
#   inflating: tesla_stock.csv

# %% [markdown]
# ## **1. Import các thư viện cần thiết**

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns

from sklearn.model_selection import train_test_split

RANDOM_SEED = 1
tf.random.set_seed(RANDOM_SEED)

# %% [markdown]
# ## **2. Trực quan hóa dữ liệu**

# %%
dataset_filepath = './tesla_stock.csv' # Khai báo đường dẫn đến file .csv của bộ dữ liệu
df = pd.read_csv(dataset_filepath, index_col=0) # Đọc file .csv thành DataFrame
df
# Out:
#                  Open        High         Low       Close    Volume  \
# Date
# 6/29/2010   19.000000   25.000000   17.540001   23.889999  18766300
# 6/30/2010   25.790001   30.420000   23.299999   23.830000  17187100
# 7/1/2010    25.000000   25.920000   20.270000   21.959999   8218800
# 7/2/2010    23.000000   23.100000   18.709999   19.200001   5139800
# 7/6/2010    20.000000   20.000000   15.830000   16.110001   6866900
# ...               ...         ...         ...         ...       ...
# 3/13/2017  244.820007  246.850006  242.779999  246.169998   3010700
# 3/14/2017  246.110001  258.119995  246.020004  258.000000   7575500
# 3/15/2017  257.000000  261.000000  254.270004  255.729996   4816600
# 3/16/2017  262.399994  265.750000  259.059998  262.049988   7100400
# 3/17/2017  264.000000  265.329987  261.200012  261.500000   6475900
#
#             Adj Close
# Date
# 6/29/2010   23.889999
# 6/30/2010   23.830000
# 7/1/2010    21.959999
# 7/2/2010    19.200001
# 7/6/2010    16.110001
# ...               ...
# 3/13/2017  246.169998
# 3/14/2017  258.000000
# 3/15/2017  255.729996
# 3/16/2017  262.049988
# 3/17/2017  261.500000
#
# [1692 rows x 6 columns]

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1692.000000  1692.000000  1692.000000  1692.000000  1.692000e+03
# mean    132.441572   134.769698   129.996223   132.428658  4.270741e+06
# std      94.309923    95.694914    92.855227    94.313187  4.295971e+06
# min      16.139999    16.629999    14.980000    15.800000  1.185000e+05
# 25%      30.000000    30.650000    29.215000    29.884999  1.194350e+06
# 50%     156.334999   162.370002   153.150002   158.160004  3.180700e+06
# 75%     220.557495   224.099999   217.119999   220.022503  5.662100e+06
# max     287.670013   291.420013   280.399994   286.040009  3.716390e+07
#
#          Adj Close
# count  1692.000000
# mean    132.428658
# std      94.313187
# min      15.800000
# 25%      29.884999
# 50%     158.160004
# 75%     220.022503
# max     286.040009

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1692 entries, 6/29/2010 to 3/17/2017
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1692 non-null   float64
#  1   High       1692 non-null   float64
#  2   Low        1692 non-null   float64
#  3   Close      1692 non-null   float64
#  4   Volume     1692 non-null   int64
#  5   Adj Close  1692 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 92.5+ KB

# %%
plt.figure(figsize=(10, 5))
df['Adj Close'].plot()
plt.title('Adjusted Closing Price of Tesla Stock')
plt.xlabel('Date')
plt.ylabel('Adj Closing Price')
plt.show()

# %%
plt.figure(figsize=(10, 5))
df['Volume'].plot()
plt.title('Volume over day of Tesla Stock')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.show()

# %% [markdown]
# ## **3. Chuẩn bị dữ liệu**

# %%
# Khai báo hàm Windowing (dùng để tạo các cặp X, y cho time series data)
def slicing_window(df, df_start_idx, df_end_idx, input_size, label_size, offset, label_name):
    features = [] # Khai báo list dùng để lưu trữ các X
    labels = [] # Khai báo list dùng để lưu trữ các y

    # Nếu df_end_idx = chỉ mục cuối cùng bảng dữ liệu, cần phải dời xuống 1 khoảng = window size
    if df_end_idx == None:
        df_end_idx = len(df) - label_size - offset

    df_start_idx = df_start_idx + input_size + offset

    # Duyệt qua từng mẫu dữ liệu
    for idx in range(df_start_idx, df_end_idx):
        feature_start_idx = idx - input_size - offset
        feature_end_idx = feature_start_idx + input_size

        label_start_idx = idx - 1
        label_end_idx = label_start_idx + label_size

        feature = df[feature_start_idx:feature_end_idx] # Lấy X
        label = df[label_name][label_start_idx:label_end_idx] # Lấy y

        features.append(feature)
        labels.append(label)

    # Chuyển list thành np.ndarrray
    features = np.array(features)
    labels = np.array(labels)

    return features, labels

# %%
INPUT_SIZE = 30
LABEL_SIZE = 1
OFFSET = 1
BATCH_SIZE = 64
TARGET_NAME = 'Adj Close'

# %%
dataset_length = len(df) # Số lượng mẫu dữ liệu trong DataFrame
TRAIN_SIZE = 0.7 # Tỉ lệ kích thước tập train
VAL_SIZE = 0.2 # Tỉ lệ kích thước tập val
# Đổi tỉ lệ thành chỉ mục
TRAIN_END_IDX = int(TRAIN_SIZE * dataset_length)
VAL_END_IDX = int(VAL_SIZE * dataset_length) + TRAIN_END_IDX

# Khởi tạo X, y cho tập train
X_train, y_train = slicing_window(df,
                                  df_start_idx=0,
                                  df_end_idx=TRAIN_END_IDX,
                                  input_size=INPUT_SIZE,
                                  label_size=LABEL_SIZE,
                                  offset=OFFSET,
                                  label_name=TARGET_NAME)

# Khởi tạo X, y cho tập val
X_val, y_val = slicing_window(df,
                                  df_start_idx=TRAIN_END_IDX,
                                  df_end_idx=VAL_END_IDX,
                                  input_size=INPUT_SIZE,
                                  label_size=LABEL_SIZE,
                                  offset=OFFSET,
                                  label_name=TARGET_NAME)

# Khởi tạo X, y cho tập test
X_test, y_test = slicing_window(df,
                                  df_start_idx=VAL_END_IDX,
                                  df_end_idx=None,
                                  input_size=INPUT_SIZE,
                                  label_size=LABEL_SIZE,
                                  offset=OFFSET,
                                  label_name=TARGET_NAME)

# %%
# Khởi tạo tf.data.Dataset
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(BATCH_SIZE)
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(BATCH_SIZE)
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(BATCH_SIZE)

# %%
# Cấu hình các tham số tối ưu cho việc đọc dữ liệu
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## **4. Xây dựng mô hình**

# %%
# Khai báo normalization layer
normalize_layer = tf.keras.layers.Normalization()
normalize_layer.adapt(np.vstack((X_train, X_val, X_test)))

# %%
# Xây dựng hàm khởi tạo model
def build_model(input_shape, output_size):
    model = tf.keras.Sequential([
        # Input layer
        tf.keras.Input(shape=input_shape, name='input_layer'),

        normalize_layer,

        # BiLSTM Layer 1
        tf.keras.layers.Bidirectional(tf.keras.layers.SimpleRNN(128,
                                                           return_sequences=True,
                                                           kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED)),
                                      name='bilstm_layer_1'),

        # BiLSTM Layer 2
        tf.keras.layers.Bidirectional(tf.keras.layers.SimpleRNN(64,
                                                           return_sequences=True,
                                                           kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED)),
                                      name='bilstm_layer_2'),

        # BiLSTM Layer 3
        tf.keras.layers.Bidirectional(tf.keras.layers.SimpleRNN(32,
                                                           return_sequences=False,
                                                           kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED)),
                                      name='bilstm_layer_3'),

        # FC Layer 1
        tf.keras.layers.Dense(32,
                              activation='relu',
                              kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED),
                              name='fc_layer_1'
                              ),

        # Output Layer
        tf.keras.layers.Dense(output_size,
                              kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED),
                              name='output_layer')
    ],
    name='bilstm_model')

    return model

# %%
INPUT_SHAPE = X_train.shape[-2:]
model = build_model(INPUT_SHAPE,
                    LABEL_SIZE)
print(X_train.shape)
print(INPUT_SHAPE)
model.summary()
# Out:
# (1153, 30, 6)
# (30, 6)
# Model: "bilstm_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizati  multiple                  13
#  on)
#
#  bilstm_layer_1 (Bidirectio  (None, 30, 256)           34560
#  nal)
#
#  bilstm_layer_2 (Bidirectio  (None, 30, 128)           41088
#  nal)
#
#  bilstm_layer_3 (Bidirectio  (None, 64)                10304
#  nal)
#
#  fc_layer_1 (Dense)          (None, 32)                2080
#
#  output_layer (Dense)        (None, 1)                 33
#
# =================================================================
# Total params: 88078 (344.06 KB)
# Trainable params: 88065 (344.00 KB)
# Non-trainable params: 13 (56.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## **5. Cấu hình mô hình**

# %%
# Khai báo một số giá trị siêu tham số
EPOCHS = 500
LR = 1e-3

# %%
# Cấu hình một số thông tin cho mô hình
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LR), # Sử dụng optimizer Adam
    loss=tf.keras.losses.MeanSquaredError(), # Sử dụng hàm loss Mean Squared Error
)

# %% [markdown]
# ## **6. Huấn luyện mô hình**

# %%
history = model.fit(train_ds,
                    validation_data=val_ds,
                    epochs=EPOCHS)
# Out:
# Epoch 1/500
# 19/19 [==============================] - 11s 214ms/step - loss: 16099.7031 - val_loss: 53028.1445
# Epoch 2/500
# 19/19 [==============================] - 2s 131ms/step - loss: 15763.0410 - val_loss: 52705.0547
# Epoch 3/500
# 19/19 [==============================] - 2s 129ms/step - loss: 15093.1309 - val_loss: 48287.9297
# Epoch 4/500
# 19/19 [==============================] - 2s 124ms/step - loss: 14177.3740 - val_loss: 46592.7266
# Epoch 5/500
# 19/19 [==============================] - 4s 188ms/step - loss: 13567.7285 - val_loss: 44797.9492
# Epoch 6/500
# 19/19 [==============================] - 3s 133ms/step - loss: 12905.2441 - val_loss: 42899.1875
# Epoch 7/500
# 19/19 [==============================] - 2s 130ms/step - loss: 12245.5010 - val_loss: 40900.2891
# Epoch 8/500
# 19/19 [==============================] - 4s 242ms/step - loss: 11556.3760 - val_loss: 38810.1445
# Epoch 9/500
# 19/19 [==============================] - 2s 125ms/step - loss: 10842.2979 - val_loss: 36644.7852
# Epoch 10/500
# 19/19 [==============================] - 2s 129ms/step - loss: 10108.3408 - val_loss: 34423.9336
# Epoch 11/500
# 19/19 [==============================] - 2s 125ms/step - loss: 9360.9072 - val_loss: 32169.2344
# Epoch 12/500
# 19/19 [==============================] - 2s 131ms/step - loss: 8608.3535 - val_loss: 29903.5469
# Epoch 13/500
# 19/19 [==============================] - 4s 208ms/step - loss: 7860.3564 - val_loss: 27649.8594
# Epoch 14/500
# 19/19 [==============================] - 3s 133ms/step - loss: 7127.1436 - val_loss: 25430.5977
# Epoch 15/500
# 19/19 [==============================] - 3s 141ms/step - loss: 6418.6582 - val_loss: 23267.0410
# Epoch 16/500
# 19/19 [==============================] - 3s 156ms/step - loss: 5743.9282 - val_loss: 21178.7773
# Epoch 17/500
# 19/19 [==============================] - 2s 130ms/step - loss: 5110.5815 - val_loss: 19183.2207
# Epoch 18/500
# 19/19 [==============================] - 2s 128ms/step - loss: 4524.4966 - val_loss: 17295.2031
# Epoch 19/500
# 19/19 [==============================] - 2s 128ms/step - loss: 3989.6033 - val_loss: 15526.6250
# Epoch 20/500
# 19/19 [==============================] - 4s 200ms/step - loss: 3507.8616 - val_loss: 13886.2324
# Epoch 21/500
# 19/19 [==============================] - 2s 130ms/step - loss: 3079.5852 - val_loss: 12379.5430
# Epoch 22/500
# 19/19 [==============================] - 2s 128ms/step - loss: 2703.7012 - val_loss: 11009.3232
# Epoch 23/500
# 19/19 [==============================] - 2s 128ms/step - loss: 2377.5703 - val_loss: 9774.7676
# Epoch 24/500
# 19/19 [==============================] - 3s 157ms/step - loss: 2098.0303 - val_loss: 8673.2803
# Epoch 25/500
# 19/19 [==============================] - 3s 153ms/step - loss: 1856.5963 - val_loss: 7697.6074
# Epoch 26/500
# 19/19 [==============================] - 2s 129ms/step - loss: 1630.7747 - val_loss: 6812.0728
# Epoch 27/500
# 19/19 [==============================] - 2s 130ms/step - loss: 1488.0431 - val_loss: 6054.8306
# Epoch 28/500
# 19/19 [==============================] - 4s 190ms/step - loss: 1306.3475 - val_loss: 5394.0137
# Epoch 29/500
# 19/19 [==============================] - 3s 138ms/step - loss: 1142.5087 - val_loss: 4764.8555
# Epoch 30/500
# 19/19 [==============================] - 2s 125ms/step - loss: 1032.0090 - val_loss: 4205.9194
# Epoch 31/500
# 19/19 [==============================] - 2s 127ms/step - loss: 914.8698 - val_loss: 3727.0154
# Epoch 32/500
# 19/19 [==============================] - 3s 184ms/step - loss: 803.7153 - val_loss: 3293.2253
# Epoch 33/500
# 19/19 [==============================] - 2s 128ms/step - loss: 772.1342 - val_loss: 2954.7517
# Epoch 34/500
# 19/19 [==============================] - 2s 131ms/step - loss: 709.5171 - val_loss: 2698.5757
# Epoch 35/500
# 19/19 [==============================] - 2s 131ms/step - loss: 658.5883 - val_loss: 2479.4622
# Epoch 36/500
# 19/19 [==============================] - 4s 190ms/step - loss: 621.0406 - val_loss: 2286.2241
# Epoch 37/500
# 19/19 [==============================] - 2s 131ms/step - loss: 597.2659 - val_loss: 2120.9072
# Epoch 38/500
# 19/19 [==============================] - 3s 132ms/step - loss: 579.0952 - val_loss: 1982.7759
# Epoch 39/500
# 19/19 [==============================] - 2s 131ms/step - loss: 565.2302 - val_loss: 1867.4097
# Epoch 40/500
# 19/19 [==============================] - 3s 134ms/step - loss: 554.6378 - val_loss: 1771.5714
# Epoch 41/500
# 19/19 [==============================] - 3s 177ms/step - loss: 546.3612 - val_loss: 1692.0055
# Epoch 42/500
# 19/19 [==============================] - 2s 130ms/step - loss: 539.6160 - val_loss: 1625.9965
# Epoch 43/500
# 19/19 [==============================] - 2s 129ms/step - loss: 531.7918 - val_loss: 1570.6533
# Epoch 44/500
# 19/19 [==============================] - 2s 129ms/step - loss: 529.9280 - val_loss: 1526.4458
# Epoch 45/500
# 19/19 [==============================] - 4s 197ms/step - loss: 560.4116 - val_loss: 1480.4988
# Epoch 46/500
# 19/19 [==============================] - 3s 138ms/step - loss: 528.8016 - val_loss: 1443.2550
# Epoch 47/500
# 19/19 [==============================] - 3s 133ms/step - loss: 527.6124 - val_loss: 1418.8967
# Epoch 48/500
# 19/19 [==============================] - 2s 126ms/step - loss: 525.5408 - val_loss: 1399.2920
# Epoch 49/500
# 19/19 [==============================] - 3s 171ms/step - loss: 523.4935 - val_loss: 1385.3693
# Epoch 50/500
# 19/19 [==============================] - 3s 149ms/step - loss: 525.7099 - val_loss: 1371.7589
# Epoch 51/500
# 19/19 [==============================] - 2s 126ms/step - loss: 524.1353 - val_loss: 1359.2084
# Epoch 52/500
# 19/19 [==============================] - 2s 130ms/step - loss: 522.1622 - val_loss: 1350.1254
# Epoch 53/500
# 19/19 [==============================] - 2s 129ms/step - loss: 521.1412 - val_loss: 1346.1584
# Epoch 54/500
# 19/19 [==============================] - 4s 197ms/step - loss: 520.7672 - val_loss: 1339.6475
# Epoch 55/500
# 19/19 [==============================] - 3s 137ms/step - loss: 536.4973 - val_loss: 1341.1859
# Epoch 56/500
# 19/19 [==============================] - 3s 133ms/step - loss: 521.5270 - val_loss: 1339.9377
# Epoch 57/500
# 19/19 [==============================] - 4s 199ms/step - loss: 519.6323 - val_loss: 1332.4797
# Epoch 58/500
# 19/19 [==============================] - 2s 129ms/step - loss: 529.2491 - val_loss: 1332.2603
# Epoch 59/500
# 19/19 [==============================] - 2s 130ms/step - loss: 532.1382 - val_loss: 1329.7003
# Epoch 60/500
# 19/19 [==============================] - 2s 129ms/step - loss: 518.8930 - val_loss: 1327.3579
# Epoch 61/500
# 19/19 [==============================] - 4s 189ms/step - loss: 521.0873 - val_loss: 1323.0585
# Epoch 62/500
# 19/19 [==============================] - 2s 129ms/step - loss: 522.4032 - val_loss: 1323.4041
# Epoch 63/500
# 19/19 [==============================] - 2s 128ms/step - loss: 517.9972 - val_loss: 1322.1454
# Epoch 64/500
# 19/19 [==============================] - 2s 131ms/step - loss: 514.3433 - val_loss: 1320.2098
# Epoch 65/500
# 19/19 [==============================] - 3s 158ms/step - loss: 512.1423 - val_loss: 1316.6140
# Epoch 66/500
# 19/19 [==============================] - 3s 163ms/step - loss: 529.7683 - val_loss: 1320.4135
# Epoch 67/500
# 19/19 [==============================] - 3s 132ms/step - loss: 524.4351 - val_loss: 1316.7313
# Epoch 68/500
# 19/19 [==============================] - 2s 131ms/step - loss: 508.7521 - val_loss: 1282.7533
# Epoch 69/500
# 19/19 [==============================] - 3s 133ms/step - loss: 436.2001 - val_loss: 1241.1871
# Epoch 70/500
# 19/19 [==============================] - 4s 197ms/step - loss: 411.7372 - val_loss: 1171.2035
# Epoch 71/500
# 19/19 [==============================] - 2s 131ms/step - loss: 411.8767 - val_loss: 1137.4152
# Epoch 72/500
# 19/19 [==============================] - 2s 132ms/step - loss: 444.9750 - val_loss: 1050.5800
# Epoch 73/500
# 19/19 [==============================] - 3s 134ms/step - loss: 360.7345 - val_loss: 1017.9495
# Epoch 74/500
# 19/19 [==============================] - 4s 195ms/step - loss: 320.0956 - val_loss: 949.1235
# Epoch 75/500
# 19/19 [==============================] - 2s 131ms/step - loss: 627.5642 - val_loss: 899.4359
# Epoch 76/500
# 19/19 [==============================] - 2s 130ms/step - loss: 282.2050 - val_loss: 756.8401
# Epoch 77/500
# 19/19 [==============================] - 3s 137ms/step - loss: 245.0199 - val_loss: 713.9391
# Epoch 78/500
# 19/19 [==============================] - 3s 133ms/step - loss: 216.8816 - val_loss: 644.6146
# Epoch 79/500
# 19/19 [==============================] - 3s 132ms/step - loss: 218.1969 - val_loss: 628.0081
# Epoch 80/500
# 19/19 [==============================] - 2s 132ms/step - loss: 322.0261 - val_loss: 590.3643
# Epoch 81/500
# 19/19 [==============================] - 4s 191ms/step - loss: 217.7855 - val_loss: 567.1494
# Epoch 82/500
# 19/19 [==============================] - 2s 126ms/step - loss: 189.4596 - val_loss: 536.9855
# Epoch 83/500
# 19/19 [==============================] - 2s 128ms/step - loss: 192.6404 - val_loss: 498.8640
# Epoch 84/500
# 19/19 [==============================] - 2s 130ms/step - loss: 181.6769 - val_loss: 469.6426
# Epoch 85/500
# 19/19 [==============================] - 3s 135ms/step - loss: 201.8633 - val_loss: 466.2383
# Epoch 86/500
# 19/19 [==============================] - 3s 173ms/step - loss: 211.9715 - val_loss: 479.2754
# Epoch 87/500
# 19/19 [==============================] - 2s 131ms/step - loss: 175.3920 - val_loss: 425.0658
# Epoch 88/500
# 19/19 [==============================] - 3s 137ms/step - loss: 149.4018 - val_loss: 403.0682
# Epoch 89/500
# 19/19 [==============================] - 4s 199ms/step - loss: 137.2125 - val_loss: 379.5159
# Epoch 90/500
# 19/19 [==============================] - 3s 133ms/step - loss: 159.9517 - val_loss: 374.3755
# Epoch 91/500
# 19/19 [==============================] - 2s 129ms/step - loss: 128.4468 - val_loss: 343.0390
# Epoch 92/500
# 19/19 [==============================] - 2s 130ms/step - loss: 147.5160 - val_loss: 350.6880
# Epoch 93/500
# 19/19 [==============================] - 3s 162ms/step - loss: 122.9235 - val_loss: 316.2340
# Epoch 94/500
# 19/19 [==============================] - 3s 154ms/step - loss: 152.2886 - val_loss: 346.4324
# Epoch 95/500
# 19/19 [==============================] - 3s 134ms/step - loss: 119.0069 - val_loss: 292.8376
# Epoch 96/500
# 19/19 [==============================] - 3s 136ms/step - loss: 131.9739 - val_loss: 308.9385
# Epoch 97/500
# 19/19 [==============================] - 4s 205ms/step - loss: 111.2318 - val_loss: 265.8228
# Epoch 98/500
# 19/19 [==============================] - 2s 130ms/step - loss: 126.1951 - val_loss: 265.6039
# Epoch 99/500
# 19/19 [==============================] - 3s 132ms/step - loss: 117.0180 - val_loss: 244.1785
# Epoch 100/500
# 19/19 [==============================] - 2s 127ms/step - loss: 150.2002 - val_loss: 301.3012
# Epoch 101/500
# 19/19 [==============================] - 4s 197ms/step - loss: 136.1480 - val_loss: 249.4125
# Epoch 102/500
# 19/19 [==============================] - 2s 129ms/step - loss: 186.3387 - val_loss: 321.9006
# Epoch 103/500
# 19/19 [==============================] - 2s 127ms/step - loss: 142.7135 - val_loss: 236.4423
# Epoch 104/500
# 19/19 [==============================] - 2s 131ms/step - loss: 155.1891 - val_loss: 320.0546
# Epoch 105/500
# 19/19 [==============================] - 3s 137ms/step - loss: 95.5439 - val_loss: 227.8367
# Epoch 106/500
# 19/19 [==============================] - 3s 179ms/step - loss: 91.3502 - val_loss: 222.4657
# Epoch 107/500
# 19/19 [==============================] - 2s 130ms/step - loss: 97.0402 - val_loss: 200.2809
# Epoch 108/500
# 19/19 [==============================] - 2s 132ms/step - loss: 99.1994 - val_loss: 197.5248
# Epoch 109/500
# 19/19 [==============================] - 3s 136ms/step - loss: 93.6515 - val_loss: 178.7979
# Epoch 110/500
# 19/19 [==============================] - 4s 193ms/step - loss: 112.8365 - val_loss: 205.6596
# Epoch 111/500
# 19/19 [==============================] - 2s 128ms/step - loss: 133.9372 - val_loss: 180.8177
# Epoch 112/500
# 19/19 [==============================] - 2s 132ms/step - loss: 139.0530 - val_loss: 224.9959
# Epoch 113/500
# 19/19 [==============================] - 3s 133ms/step - loss: 104.9545 - val_loss: 173.3395
# Epoch 114/500
# 19/19 [==============================] - 4s 191ms/step - loss: 98.5687 - val_loss: 173.3189
# Epoch 115/500
# 19/19 [==============================] - 2s 130ms/step - loss: 86.4521 - val_loss: 148.3119
# Epoch 116/500
# 19/19 [==============================] - 2s 130ms/step - loss: 91.2041 - val_loss: 151.7799
# Epoch 117/500
# 19/19 [==============================] - 3s 132ms/step - loss: 83.4565 - val_loss: 136.4872
# Epoch 118/500
# 19/19 [==============================] - 4s 198ms/step - loss: 89.8576 - val_loss: 143.3095
# Epoch 119/500
# 19/19 [==============================] - 2s 129ms/step - loss: 80.0273 - val_loss: 125.4850
# Epoch 120/500
# 19/19 [==============================] - 2s 129ms/step - loss: 84.4678 - val_loss: 134.1806
# Epoch 121/500
# 19/19 [==============================] - 2s 130ms/step - loss: 77.0644 - val_loss: 118.2021
# Epoch 122/500
# 19/19 [==============================] - 3s 143ms/step - loss: 83.9827 - val_loss: 128.6240
# Epoch 123/500
# 19/19 [==============================] - 2s 130ms/step - loss: 79.7686 - val_loss: 111.0814
# Epoch 124/500
# 19/19 [==============================] - 2s 128ms/step - loss: 89.4625 - val_loss: 123.9967
# Epoch 125/500
# 19/19 [==============================] - 2s 129ms/step - loss: 85.6878 - val_loss: 107.4578
# Epoch 126/500
# 19/19 [==============================] - 4s 196ms/step - loss: 90.9869 - val_loss: 124.2193
# Epoch 127/500
# 19/19 [==============================] - 3s 133ms/step - loss: 79.7887 - val_loss: 105.0077
# Epoch 128/500
# 19/19 [==============================] - 2s 131ms/step - loss: 85.1668 - val_loss: 114.3690
# Epoch 129/500
# 19/19 [==============================] - 3s 135ms/step - loss: 81.8323 - val_loss: 101.6004
# Epoch 130/500
# 19/19 [==============================] - 3s 157ms/step - loss: 83.1690 - val_loss: 112.7324
# Epoch 131/500
# 19/19 [==============================] - 3s 153ms/step - loss: 72.7023 - val_loss: 97.8008
# Epoch 132/500
# 19/19 [==============================] - 2s 130ms/step - loss: 76.7214 - val_loss: 104.4731
# Epoch 133/500
# 19/19 [==============================] - 3s 133ms/step - loss: 69.5284 - val_loss: 94.8869
# Epoch 134/500
# 19/19 [==============================] - 3s 135ms/step - loss: 75.0006 - val_loss: 100.7697
# Epoch 135/500
# 19/19 [==============================] - 4s 193ms/step - loss: 68.6118 - val_loss: 92.1081
# Epoch 136/500
# 19/19 [==============================] - 3s 133ms/step - loss: 75.1553 - val_loss: 96.2548
# Epoch 137/500
# 19/19 [==============================] - 3s 132ms/step - loss: 71.1709 - val_loss: 89.7570
# Epoch 138/500
# 19/19 [==============================] - 2s 129ms/step - loss: 78.8066 - val_loss: 100.5747
# Epoch 139/500
# 19/19 [==============================] - 4s 196ms/step - loss: 69.4553 - val_loss: 88.6144
# Epoch 140/500
# 19/19 [==============================] - 3s 134ms/step - loss: 73.9679 - val_loss: 93.5820
# Epoch 141/500
# 19/19 [==============================] - 2s 129ms/step - loss: 72.0415 - val_loss: 85.4390
# Epoch 142/500
# 19/19 [==============================] - 2s 130ms/step - loss: 78.4945 - val_loss: 97.0589
# Epoch 143/500
# 19/19 [==============================] - 4s 193ms/step - loss: 72.8679 - val_loss: 82.6857
# Epoch 144/500
# 19/19 [==============================] - 2s 128ms/step - loss: 82.4347 - val_loss: 93.5559
# Epoch 145/500
# 19/19 [==============================] - 2s 126ms/step - loss: 82.6297 - val_loss: 81.8736
# Epoch 146/500
# 19/19 [==============================] - 2s 132ms/step - loss: 92.4484 - val_loss: 87.8566
# Epoch 147/500
# 19/19 [==============================] - 3s 175ms/step - loss: 92.8649 - val_loss: 86.5263
# Epoch 148/500
# 19/19 [==============================] - 3s 136ms/step - loss: 87.9155 - val_loss: 91.2602
# Epoch 149/500
# 19/19 [==============================] - 2s 131ms/step - loss: 89.3603 - val_loss: 84.3647
# Epoch 150/500
# 19/19 [==============================] - 3s 132ms/step - loss: 113.7691 - val_loss: 99.3220
# Epoch 151/500
# 19/19 [==============================] - 4s 192ms/step - loss: 78.7253 - val_loss: 84.1225
# Epoch 152/500
# 19/19 [==============================] - 2s 131ms/step - loss: 79.1073 - val_loss: 93.0653
# Epoch 153/500
# 19/19 [==============================] - 2s 130ms/step - loss: 71.5560 - val_loss: 82.0761
# Epoch 154/500
# 19/19 [==============================] - 2s 130ms/step - loss: 71.4025 - val_loss: 86.8638
# Epoch 155/500
# 19/19 [==============================] - 4s 192ms/step - loss: 64.3360 - val_loss: 80.7296
# Epoch 156/500
# 19/19 [==============================] - 3s 136ms/step - loss: 67.1462 - val_loss: 80.4034
# Epoch 157/500
# 19/19 [==============================] - 3s 134ms/step - loss: 62.6419 - val_loss: 76.8579
# Epoch 158/500
# 19/19 [==============================] - 3s 132ms/step - loss: 59.3776 - val_loss: 72.0834
# Epoch 159/500
# 19/19 [==============================] - 4s 207ms/step - loss: 54.4494 - val_loss: 69.2128
# Epoch 160/500
# 19/19 [==============================] - 2s 132ms/step - loss: 56.2027 - val_loss: 74.4266
# Epoch 161/500
# 19/19 [==============================] - 2s 131ms/step - loss: 55.0000 - val_loss: 66.0616
# Epoch 162/500
# 19/19 [==============================] - 2s 132ms/step - loss: 64.0593 - val_loss: 69.4262
# Epoch 163/500
# 19/19 [==============================] - 4s 188ms/step - loss: 66.6670 - val_loss: 63.3661
# Epoch 164/500
# 19/19 [==============================] - 2s 129ms/step - loss: 68.2371 - val_loss: 71.4498
# Epoch 165/500
# 19/19 [==============================] - 2s 129ms/step - loss: 56.7859 - val_loss: 59.8513
# Epoch 166/500
# 19/19 [==============================] - 2s 131ms/step - loss: 54.3496 - val_loss: 62.7393
# Epoch 167/500
# 19/19 [==============================] - 4s 192ms/step - loss: 54.7503 - val_loss: 57.6433
# Epoch 168/500
# 19/19 [==============================] - 3s 133ms/step - loss: 65.2459 - val_loss: 62.7799
# Epoch 169/500
# 19/19 [==============================] - 3s 136ms/step - loss: 65.4437 - val_loss: 62.5727
# Epoch 170/500
# 19/19 [==============================] - 3s 133ms/step - loss: 87.6004 - val_loss: 63.1492
# Epoch 171/500
# 19/19 [==============================] - 5s 244ms/step - loss: 132.1491 - val_loss: 86.0152
# Epoch 172/500
# 19/19 [==============================] - 3s 132ms/step - loss: 230.5453 - val_loss: 100.1669
# Epoch 173/500
# 19/19 [==============================] - 2s 131ms/step - loss: 274.7504 - val_loss: 235.7072
# Epoch 174/500
# 19/19 [==============================] - 4s 191ms/step - loss: 251.3794 - val_loss: 165.8299
# Epoch 175/500
# 19/19 [==============================] - 3s 132ms/step - loss: 364.2741 - val_loss: 139.3871
# Epoch 176/500
# 19/19 [==============================] - 3s 132ms/step - loss: 796.5291 - val_loss: 42337.6445
# Epoch 177/500
# 19/19 [==============================] - 3s 134ms/step - loss: 583.7552 - val_loss: 326.9700
# Epoch 178/500
# 19/19 [==============================] - 4s 203ms/step - loss: 235.6050 - val_loss: 309.0250
# Epoch 179/500
# 19/19 [==============================] - 2s 127ms/step - loss: 240.5652 - val_loss: 406.2996
# Epoch 180/500
# 19/19 [==============================] - 3s 133ms/step - loss: 219.1452 - val_loss: 333.5902
# Epoch 181/500
# 19/19 [==============================] - 2s 132ms/step - loss: 142.8053 - val_loss: 213.8668
# Epoch 182/500
# 19/19 [==============================] - 3s 174ms/step - loss: 105.9105 - val_loss: 172.4663
# Epoch 183/500
# 19/19 [==============================] - 3s 133ms/step - loss: 99.1054 - val_loss: 167.8773
# Epoch 184/500
# 19/19 [==============================] - 3s 133ms/step - loss: 99.0553 - val_loss: 151.5488
# Epoch 185/500
# 19/19 [==============================] - 2s 129ms/step - loss: 87.5965 - val_loss: 148.7656
# Epoch 186/500
# 19/19 [==============================] - 4s 193ms/step - loss: 83.9282 - val_loss: 128.5029
# Epoch 187/500
# 19/19 [==============================] - 3s 132ms/step - loss: 74.0785 - val_loss: 289.2486
# Epoch 188/500
# 19/19 [==============================] - 3s 132ms/step - loss: 71.2291 - val_loss: 447.1211
# Epoch 189/500
# 19/19 [==============================] - 2s 132ms/step - loss: 66.3862 - val_loss: 437.9189
# Epoch 190/500
# 19/19 [==============================] - 4s 193ms/step - loss: 62.3122 - val_loss: 411.8674
# Epoch 191/500
# 19/19 [==============================] - 2s 132ms/step - loss: 58.4726 - val_loss: 401.8087
# Epoch 192/500
# 19/19 [==============================] - 2s 131ms/step - loss: 61.3169 - val_loss: 398.5877
# Epoch 193/500
# 19/19 [==============================] - 2s 129ms/step - loss: 548.6757 - val_loss: 24536.0938
# Epoch 194/500
# 19/19 [==============================] - 4s 197ms/step - loss: 9541.5898 - val_loss: 47118.8789
# Epoch 195/500
# 19/19 [==============================] - 3s 133ms/step - loss: 5112.5366 - val_loss: 1506.6151
# Epoch 196/500
# 19/19 [==============================] - 2s 132ms/step - loss: 3226.0222 - val_loss: 11003.2412
# Epoch 197/500
# 19/19 [==============================] - 3s 133ms/step - loss: 281.7288 - val_loss: 687.5441
# Epoch 198/500
# 19/19 [==============================] - 3s 151ms/step - loss: 1508.7365 - val_loss: 269.9671
# Epoch 199/500
# 19/19 [==============================] - 3s 164ms/step - loss: 1005.1912 - val_loss: 173.7354
# Epoch 200/500
# 19/19 [==============================] - 2s 129ms/step - loss: 166.8341 - val_loss: 147.7689
# Epoch 201/500
# 19/19 [==============================] - 3s 133ms/step - loss: 183.2693 - val_loss: 126.3146
# Epoch 202/500
# 19/19 [==============================] - 4s 189ms/step - loss: 138.2684 - val_loss: 123.9639
# Epoch 203/500
# 19/19 [==============================] - 2s 131ms/step - loss: 139.1475 - val_loss: 112.3728
# Epoch 204/500
# 19/19 [==============================] - 3s 133ms/step - loss: 122.9397 - val_loss: 107.0015
# Epoch 205/500
# 19/19 [==============================] - 2s 130ms/step - loss: 125.3258 - val_loss: 95.5416
# Epoch 206/500
# 19/19 [==============================] - 3s 135ms/step - loss: 117.4371 - val_loss: 90.2899
# Epoch 207/500
# 19/19 [==============================] - 3s 175ms/step - loss: 1111.3505 - val_loss: 87.5395
# Epoch 208/500
# 19/19 [==============================] - 3s 133ms/step - loss: 3634.6304 - val_loss: 243.1007
# Epoch 209/500
# 19/19 [==============================] - 2s 129ms/step - loss: 251.5475 - val_loss: 114.5032
# Epoch 210/500
# 19/19 [==============================] - 3s 176ms/step - loss: 207.4384 - val_loss: 96.4117
# Epoch 211/500
# 19/19 [==============================] - 3s 142ms/step - loss: 252.7318 - val_loss: 124.4231
# Epoch 212/500
# 19/19 [==============================] - 2s 130ms/step - loss: 215.5125 - val_loss: 108.9370
# Epoch 213/500
# 19/19 [==============================] - 2s 130ms/step - loss: 205.6783 - val_loss: 114.1537
# Epoch 214/500
# 19/19 [==============================] - 2s 130ms/step - loss: 175.2789 - val_loss: 96.4365
# Epoch 215/500
# 19/19 [==============================] - 4s 201ms/step - loss: 171.7891 - val_loss: 114.6150
# Epoch 216/500
# 19/19 [==============================] - 2s 130ms/step - loss: 137.6223 - val_loss: 100.1999
# Epoch 217/500
# 19/19 [==============================] - 3s 133ms/step - loss: 126.3094 - val_loss: 78.2272
# Epoch 218/500
# 19/19 [==============================] - 3s 152ms/step - loss: 116.7508 - val_loss: 79.2030
# Epoch 219/500
# 19/19 [==============================] - 3s 170ms/step - loss: 113.2129 - val_loss: 69.7002
# Epoch 220/500
# 19/19 [==============================] - 3s 130ms/step - loss: 110.6574 - val_loss: 68.7557
# Epoch 221/500
# 19/19 [==============================] - 3s 133ms/step - loss: 108.8692 - val_loss: 64.2336
# Epoch 222/500
# 19/19 [==============================] - 3s 134ms/step - loss: 107.2237 - val_loss: 62.8810
# Epoch 223/500
# 19/19 [==============================] - 4s 188ms/step - loss: 105.7504 - val_loss: 60.0417
# Epoch 224/500
# 19/19 [==============================] - 2s 127ms/step - loss: 104.2920 - val_loss: 58.7877
# Epoch 225/500
# 19/19 [==============================] - 2s 125ms/step - loss: 102.9326 - val_loss: 56.7312
# Epoch 226/500
# 19/19 [==============================] - 2s 128ms/step - loss: 101.5541 - val_loss: 55.6243
# Epoch 227/500
# 19/19 [==============================] - 3s 158ms/step - loss: 100.2724 - val_loss: 53.9962
# Epoch 228/500
# 19/19 [==============================] - 3s 154ms/step - loss: 98.9143 - val_loss: 53.0376
# Epoch 229/500
# 19/19 [==============================] - 2s 129ms/step - loss: 97.6870 - val_loss: 51.7035
# Epoch 230/500
# 19/19 [==============================] - 3s 136ms/step - loss: 96.4163 - val_loss: 50.9068
# Epoch 231/500
# 19/19 [==============================] - 4s 201ms/step - loss: 95.2750 - val_loss: 49.8137
# Epoch 232/500
# 19/19 [==============================] - 2s 130ms/step - loss: 94.0631 - val_loss: 49.2014
# Epoch 233/500
# 19/19 [==============================] - 2s 129ms/step - loss: 93.1120 - val_loss: 48.3133
# Epoch 234/500
# 19/19 [==============================] - 2s 130ms/step - loss: 92.0609 - val_loss: 47.9166
# Epoch 235/500
# 19/19 [==============================] - 4s 193ms/step - loss: 91.6668 - val_loss: 47.2164
# Epoch 236/500
# 19/19 [==============================] - 3s 133ms/step - loss: 91.2908 - val_loss: 47.2076
# Epoch 237/500
# 19/19 [==============================] - 2s 126ms/step - loss: 92.9240 - val_loss: 46.8059
# Epoch 238/500
# 19/19 [==============================] - 2s 131ms/step - loss: 94.3807 - val_loss: 47.2950
# Epoch 239/500
# 19/19 [==============================] - 4s 200ms/step - loss: 101.8722 - val_loss: 46.4844
# Epoch 240/500
# 19/19 [==============================] - 2s 129ms/step - loss: 104.1641 - val_loss: 48.5093
# Epoch 241/500
# 19/19 [==============================] - 2s 128ms/step - loss: 117.8497 - val_loss: 48.2365
# Epoch 242/500
# 19/19 [==============================] - 2s 128ms/step - loss: 126.3096 - val_loss: 85.7443
# Epoch 243/500
# 19/19 [==============================] - 4s 193ms/step - loss: 133.3080 - val_loss: 57.5225
# Epoch 244/500
# 19/19 [==============================] - 3s 131ms/step - loss: 126.3066 - val_loss: 63.3517
# Epoch 245/500
# 19/19 [==============================] - 2s 128ms/step - loss: 156.3116 - val_loss: 53.8695
# Epoch 246/500
# 19/19 [==============================] - 2s 130ms/step - loss: 160.2463 - val_loss: 100.7989
# Epoch 247/500
# 19/19 [==============================] - 3s 179ms/step - loss: 173.1129 - val_loss: 88.5537
# Epoch 248/500
# 19/19 [==============================] - 3s 133ms/step - loss: 169.0247 - val_loss: 102.5364
# Epoch 249/500
# 19/19 [==============================] - 2s 130ms/step - loss: 180.6934 - val_loss: 57.9284
# Epoch 250/500
# 19/19 [==============================] - 2s 130ms/step - loss: 175.5852 - val_loss: 65.0224
# Epoch 251/500
# 19/19 [==============================] - 4s 216ms/step - loss: 181.7577 - val_loss: 67.1443
# Epoch 252/500
# 19/19 [==============================] - 3s 146ms/step - loss: 143.2259 - val_loss: 115.6483
# Epoch 253/500
# 19/19 [==============================] - 2s 131ms/step - loss: 122.1150 - val_loss: 68.1370
# Epoch 254/500
# 19/19 [==============================] - 2s 131ms/step - loss: 109.1088 - val_loss: 65.3494
# Epoch 255/500
# 19/19 [==============================] - 4s 194ms/step - loss: 107.3252 - val_loss: 54.3777
# Epoch 256/500
# 19/19 [==============================] - 2s 128ms/step - loss: 102.1476 - val_loss: 60.9382
# Epoch 257/500
# 19/19 [==============================] - 2s 128ms/step - loss: 97.8386 - val_loss: 51.7360
# Epoch 258/500
# 19/19 [==============================] - 3s 133ms/step - loss: 99.3640 - val_loss: 55.8954
# Epoch 259/500
# 19/19 [==============================] - 4s 192ms/step - loss: 94.1918 - val_loss: 49.6159
# Epoch 260/500
# 19/19 [==============================] - 2s 130ms/step - loss: 92.2072 - val_loss: 54.1333
# Epoch 261/500
# 19/19 [==============================] - 2s 125ms/step - loss: 90.8841 - val_loss: 48.8253
# Epoch 262/500
# 19/19 [==============================] - 2s 129ms/step - loss: 88.6819 - val_loss: 55.1065
# Epoch 263/500
# 19/19 [==============================] - 2s 131ms/step - loss: 92.2450 - val_loss: 47.9376
# Epoch 264/500
# 19/19 [==============================] - 4s 186ms/step - loss: 87.5553 - val_loss: 55.1336
# Epoch 265/500
# 19/19 [==============================] - 2s 128ms/step - loss: 91.0784 - val_loss: 47.9790
# Epoch 266/500
# 19/19 [==============================] - 2s 130ms/step - loss: 87.6308 - val_loss: 56.8671
# Epoch 267/500
# 19/19 [==============================] - 3s 133ms/step - loss: 91.3082 - val_loss: 48.4535
# Epoch 268/500
# 19/19 [==============================] - 4s 196ms/step - loss: 87.8224 - val_loss: 60.3554
# Epoch 269/500
# 19/19 [==============================] - 2s 129ms/step - loss: 92.3602 - val_loss: 49.4904
# Epoch 270/500
# 19/19 [==============================] - 3s 132ms/step - loss: 87.8965 - val_loss: 62.9831
# Epoch 271/500
# 19/19 [==============================] - 3s 136ms/step - loss: 91.5523 - val_loss: 50.3847
# Epoch 272/500
# 19/19 [==============================] - 4s 193ms/step - loss: 86.2814 - val_loss: 63.1937
# Epoch 273/500
# 19/19 [==============================] - 2s 130ms/step - loss: 90.1848 - val_loss: 50.1944
# Epoch 274/500
# 19/19 [==============================] - 2s 130ms/step - loss: 83.3225 - val_loss: 63.1446
# Epoch 275/500
# 19/19 [==============================] - 2s 127ms/step - loss: 86.4631 - val_loss: 49.2477
# Epoch 276/500
# 19/19 [==============================] - 4s 198ms/step - loss: 79.1209 - val_loss: 61.0620
# Epoch 277/500
# 19/19 [==============================] - 2s 132ms/step - loss: 82.3767 - val_loss: 48.5852
# Epoch 278/500
# 19/19 [==============================] - 2s 127ms/step - loss: 75.6047 - val_loss: 59.5922
# Epoch 279/500
# 19/19 [==============================] - 2s 131ms/step - loss: 79.2137 - val_loss: 47.9258
# Epoch 280/500
# 19/19 [==============================] - 3s 141ms/step - loss: 72.9941 - val_loss: 58.0966
# Epoch 281/500
# 19/19 [==============================] - 3s 134ms/step - loss: 77.4065 - val_loss: 47.4369
# Epoch 282/500
# 19/19 [==============================] - 3s 133ms/step - loss: 71.6561 - val_loss: 58.4459
# Epoch 283/500
# 19/19 [==============================] - 3s 136ms/step - loss: 76.4955 - val_loss: 47.4701
# Epoch 284/500
# 19/19 [==============================] - 4s 193ms/step - loss: 70.7894 - val_loss: 57.8994
# Epoch 285/500
# 19/19 [==============================] - 2s 127ms/step - loss: 76.0404 - val_loss: 47.5505
# Epoch 286/500
# 19/19 [==============================] - 2s 129ms/step - loss: 70.5703 - val_loss: 59.5528
# Epoch 287/500
# 19/19 [==============================] - 3s 133ms/step - loss: 75.4661 - val_loss: 47.8575
# Epoch 288/500
# 19/19 [==============================] - 3s 161ms/step - loss: 69.8139 - val_loss: 59.2572
# Epoch 289/500
# 19/19 [==============================] - 2s 128ms/step - loss: 74.4108 - val_loss: 47.9293
# Epoch 290/500
# 19/19 [==============================] - 3s 132ms/step - loss: 68.9132 - val_loss: 61.1032
# Epoch 291/500
# 19/19 [==============================] - 2s 130ms/step - loss: 72.0677 - val_loss: 47.9298
# Epoch 292/500
# 19/19 [==============================] - 3s 186ms/step - loss: 66.5968 - val_loss: 59.5609
# Epoch 293/500
# 19/19 [==============================] - 2s 130ms/step - loss: 68.7672 - val_loss: 47.7721
# Epoch 294/500
# 19/19 [==============================] - 3s 134ms/step - loss: 64.1816 - val_loss: 59.2084
# Epoch 295/500
# 19/19 [==============================] - 2s 130ms/step - loss: 63.6428 - val_loss: 47.3228
# Epoch 296/500
# 19/19 [==============================] - 3s 152ms/step - loss: 62.4491 - val_loss: 56.0434
# Epoch 297/500
# 19/19 [==============================] - 2s 131ms/step - loss: 58.2816 - val_loss: 47.2734
# Epoch 298/500
# 19/19 [==============================] - 2s 133ms/step - loss: 58.7386 - val_loss: 53.0242
# Epoch 299/500
# 19/19 [==============================] - 2s 129ms/step - loss: 53.6298 - val_loss: 47.0926
# Epoch 300/500
# 19/19 [==============================] - 4s 192ms/step - loss: 53.7559 - val_loss: 50.3015
# Epoch 301/500
# 19/19 [==============================] - 3s 133ms/step - loss: 50.8701 - val_loss: 47.2573
# Epoch 302/500
# 19/19 [==============================] - 2s 129ms/step - loss: 52.8280 - val_loss: 48.8011
# Epoch 303/500
# 19/19 [==============================] - 2s 131ms/step - loss: 49.3109 - val_loss: 47.8816
# Epoch 304/500
# 19/19 [==============================] - 4s 189ms/step - loss: 51.4607 - val_loss: 47.5410
# Epoch 305/500
# 19/19 [==============================] - 2s 128ms/step - loss: 48.2681 - val_loss: 48.8944
# Epoch 306/500
# 19/19 [==============================] - 2s 127ms/step - loss: 51.8597 - val_loss: 46.4556
# Epoch 307/500
# 19/19 [==============================] - 2s 131ms/step - loss: 48.6126 - val_loss: 48.9835
# Epoch 308/500
# 19/19 [==============================] - 3s 185ms/step - loss: 52.0793 - val_loss: 45.7057
# Epoch 309/500
# 19/19 [==============================] - 3s 131ms/step - loss: 51.5832 - val_loss: 48.3448
# Epoch 310/500
# 19/19 [==============================] - 2s 131ms/step - loss: 55.3771 - val_loss: 45.6505
# Epoch 311/500
# 19/19 [==============================] - 2s 130ms/step - loss: 59.1660 - val_loss: 46.6468
# Epoch 312/500
# 19/19 [==============================] - 2s 129ms/step - loss: 62.5894 - val_loss: 47.4401
# Epoch 313/500
# 19/19 [==============================] - 4s 196ms/step - loss: 73.6454 - val_loss: 46.5904
# Epoch 314/500
# 19/19 [==============================] - 2s 131ms/step - loss: 77.4614 - val_loss: 56.5288
# Epoch 315/500
# 19/19 [==============================] - 3s 132ms/step - loss: 90.1128 - val_loss: 50.0476
# Epoch 316/500
# 19/19 [==============================] - 3s 144ms/step - loss: 90.0563 - val_loss: 78.8026
# Epoch 317/500
# 19/19 [==============================] - 3s 166ms/step - loss: 99.4453 - val_loss: 69.4895
# Epoch 318/500
# 19/19 [==============================] - 3s 134ms/step - loss: 94.3300 - val_loss: 62.7372
# Epoch 319/500
# 19/19 [==============================] - 2s 128ms/step - loss: 97.7832 - val_loss: 56.4299
# Epoch 320/500
# 19/19 [==============================] - 3s 188ms/step - loss: 94.6304 - val_loss: 57.5869
# Epoch 321/500
# 19/19 [==============================] - 2s 129ms/step - loss: 112.6907 - val_loss: 62.3846
# Epoch 322/500
# 19/19 [==============================] - 3s 135ms/step - loss: 96.8708 - val_loss: 80.4297
# Epoch 323/500
# 19/19 [==============================] - 2s 132ms/step - loss: 87.0762 - val_loss: 56.3122
# Epoch 324/500
# 19/19 [==============================] - 3s 133ms/step - loss: 81.5125 - val_loss: 90.7119
# Epoch 325/500
# 19/19 [==============================] - 3s 182ms/step - loss: 68.7577 - val_loss: 61.5248
# Epoch 326/500
# 19/19 [==============================] - 2s 131ms/step - loss: 58.6935 - val_loss: 82.6557
# Epoch 327/500
# 19/19 [==============================] - 2s 132ms/step - loss: 48.1012 - val_loss: 47.3062
# Epoch 328/500
# 19/19 [==============================] - 2s 127ms/step - loss: 40.8218 - val_loss: 52.4394
# Epoch 329/500
# 19/19 [==============================] - 4s 192ms/step - loss: 38.4754 - val_loss: 47.2735
# Epoch 330/500
# 19/19 [==============================] - 2s 131ms/step - loss: 36.4283 - val_loss: 46.4330
# Epoch 331/500
# 19/19 [==============================] - 3s 133ms/step - loss: 33.6704 - val_loss: 49.2507
# Epoch 332/500
# 19/19 [==============================] - 2s 127ms/step - loss: 45.4600 - val_loss: 42.8768
# Epoch 333/500
# 19/19 [==============================] - 3s 148ms/step - loss: 33.3912 - val_loss: 45.8011
# Epoch 334/500
# 19/19 [==============================] - 3s 164ms/step - loss: 33.7649 - val_loss: 45.6103
# Epoch 335/500
# 19/19 [==============================] - 4s 192ms/step - loss: 34.9612 - val_loss: 43.9757
# Epoch 336/500
# 19/19 [==============================] - 2s 129ms/step - loss: 27.9398 - val_loss: 48.0238
# Epoch 337/500
# 19/19 [==============================] - 3s 135ms/step - loss: 34.3829 - val_loss: 45.2337
# Epoch 338/500
# 19/19 [==============================] - 3s 132ms/step - loss: 30.1707 - val_loss: 45.4361
# Epoch 339/500
# 19/19 [==============================] - 2s 131ms/step - loss: 27.9374 - val_loss: 43.3399
# Epoch 340/500
# 19/19 [==============================] - 3s 132ms/step - loss: 27.3579 - val_loss: 48.5576
# Epoch 341/500
# 19/19 [==============================] - 4s 199ms/step - loss: 37.7381 - val_loss: 44.2653
# Epoch 342/500
# 19/19 [==============================] - 3s 133ms/step - loss: 31.5296 - val_loss: 44.1780
# Epoch 343/500
# 19/19 [==============================] - 3s 136ms/step - loss: 26.8707 - val_loss: 42.3423
# Epoch 344/500
# 19/19 [==============================] - 3s 176ms/step - loss: 26.8451 - val_loss: 46.7477
# Epoch 345/500
# 19/19 [==============================] - 3s 144ms/step - loss: 39.8719 - val_loss: 45.0354
# Epoch 346/500
# 19/19 [==============================] - 3s 135ms/step - loss: 34.6072 - val_loss: 44.0735
# Epoch 347/500
# 19/19 [==============================] - 4s 199ms/step - loss: 31.5036 - val_loss: 41.1586
# Epoch 348/500
# 19/19 [==============================] - 3s 135ms/step - loss: 26.9483 - val_loss: 46.4709
# Epoch 349/500
# 19/19 [==============================] - 2s 128ms/step - loss: 39.2786 - val_loss: 43.9357
# Epoch 350/500
# 19/19 [==============================] - 4s 197ms/step - loss: 32.5017 - val_loss: 48.1799
# Epoch 351/500
# 19/19 [==============================] - 2s 127ms/step - loss: 39.9679 - val_loss: 45.2274
# Epoch 352/500
# 19/19 [==============================] - 2s 132ms/step - loss: 30.0289 - val_loss: 48.4124
# Epoch 353/500
# 19/19 [==============================] - 2s 129ms/step - loss: 42.5161 - val_loss: 45.8232
# Epoch 354/500
# 19/19 [==============================] - 4s 195ms/step - loss: 29.4855 - val_loss: 49.5793
# Epoch 355/500
# 19/19 [==============================] - 2s 131ms/step - loss: 44.2596 - val_loss: 42.8949
# Epoch 356/500
# 19/19 [==============================] - 3s 133ms/step - loss: 29.0582 - val_loss: 44.0063
# Epoch 357/500
# 19/19 [==============================] - 3s 135ms/step - loss: 30.6192 - val_loss: 42.6831
# Epoch 358/500
# 19/19 [==============================] - 4s 190ms/step - loss: 24.8292 - val_loss: 44.9200
# Epoch 359/500
# 19/19 [==============================] - 3s 134ms/step - loss: 30.5459 - val_loss: 42.2219
# Epoch 360/500
# 19/19 [==============================] - 2s 128ms/step - loss: 32.4915 - val_loss: 50.8904
# Epoch 361/500
# 19/19 [==============================] - 3s 136ms/step - loss: 56.9892 - val_loss: 42.3631
# Epoch 362/500
# 19/19 [==============================] - 4s 180ms/step - loss: 61.3117 - val_loss: 56.3274
# Epoch 363/500
# 19/19 [==============================] - 3s 132ms/step - loss: 88.0655 - val_loss: 59.7612
# Epoch 364/500
# 19/19 [==============================] - 2s 126ms/step - loss: 104.2183 - val_loss: 70.4741
# Epoch 365/500
# 19/19 [==============================] - 2s 131ms/step - loss: 123.7135 - val_loss: 78.3649
# Epoch 366/500
# 19/19 [==============================] - 4s 190ms/step - loss: 91.2030 - val_loss: 96.4381
# Epoch 367/500
# 19/19 [==============================] - 2s 132ms/step - loss: 136.5453 - val_loss: 76.2909
# Epoch 368/500
# 19/19 [==============================] - 2s 127ms/step - loss: 105.3399 - val_loss: 97.0735
# Epoch 369/500
# 19/19 [==============================] - 2s 127ms/step - loss: 86.9192 - val_loss: 61.5034
# Epoch 370/500
# 19/19 [==============================] - 4s 195ms/step - loss: 121.4691 - val_loss: 54.1967
# Epoch 371/500
# 19/19 [==============================] - 3s 134ms/step - loss: 134.8695 - val_loss: 85.3055
# Epoch 372/500
# 19/19 [==============================] - 3s 135ms/step - loss: 112.4033 - val_loss: 72.0164
# Epoch 373/500
# 19/19 [==============================] - 4s 196ms/step - loss: 76.7048 - val_loss: 52.8743
# Epoch 374/500
# 19/19 [==============================] - 2s 132ms/step - loss: 69.9366 - val_loss: 60.9928
# Epoch 375/500
# 19/19 [==============================] - 3s 138ms/step - loss: 72.6325 - val_loss: 49.7281
# Epoch 376/500
# 19/19 [==============================] - 3s 171ms/step - loss: 87.3605 - val_loss: 53.0573
# Epoch 377/500
# 19/19 [==============================] - 3s 157ms/step - loss: 96.9673 - val_loss: 127.5886
# Epoch 378/500
# 19/19 [==============================] - 3s 139ms/step - loss: 70.5931 - val_loss: 78.0482
# Epoch 379/500
# 19/19 [==============================] - 3s 138ms/step - loss: 52.8908 - val_loss: 50.2975
# Epoch 380/500
# 19/19 [==============================] - 4s 202ms/step - loss: 51.3333 - val_loss: 44.8301
# Epoch 381/500
# 19/19 [==============================] - 3s 133ms/step - loss: 50.6987 - val_loss: 49.6738
# Epoch 382/500
# 19/19 [==============================] - 3s 136ms/step - loss: 44.9774 - val_loss: 53.5822
# Epoch 383/500
# 19/19 [==============================] - 3s 132ms/step - loss: 46.4022 - val_loss: 48.2088
# Epoch 384/500
# 19/19 [==============================] - 3s 184ms/step - loss: 35.0514 - val_loss: 47.7938
# Epoch 385/500
# 19/19 [==============================] - 3s 134ms/step - loss: 36.5645 - val_loss: 43.3708
# Epoch 386/500
# 19/19 [==============================] - 2s 129ms/step - loss: 28.0149 - val_loss: 43.5251
# Epoch 387/500
# 19/19 [==============================] - 3s 149ms/step - loss: 27.1165 - val_loss: 42.8034
# Epoch 388/500
# 19/19 [==============================] - 2s 132ms/step - loss: 25.1996 - val_loss: 42.9511
# Epoch 389/500
# 19/19 [==============================] - 3s 133ms/step - loss: 26.2470 - val_loss: 41.6906
# Epoch 390/500
# 19/19 [==============================] - 3s 131ms/step - loss: 24.3289 - val_loss: 42.3022
# Epoch 391/500
# 19/19 [==============================] - 4s 194ms/step - loss: 25.7658 - val_loss: 40.3654
# Epoch 392/500
# 19/19 [==============================] - 3s 134ms/step - loss: 22.8004 - val_loss: 41.7024
# Epoch 393/500
# 19/19 [==============================] - 3s 135ms/step - loss: 26.5203 - val_loss: 40.2996
# Epoch 394/500
# 19/19 [==============================] - 3s 134ms/step - loss: 24.0493 - val_loss: 42.4759
# Epoch 395/500
# 19/19 [==============================] - 4s 200ms/step - loss: 31.8622 - val_loss: 40.8095
# Epoch 396/500
# 19/19 [==============================] - 2s 131ms/step - loss: 26.0718 - val_loss: 42.9364
# Epoch 397/500
# 19/19 [==============================] - 3s 134ms/step - loss: 35.7503 - val_loss: 42.8647
# Epoch 398/500
# 19/19 [==============================] - 3s 135ms/step - loss: 25.1800 - val_loss: 42.6265
# Epoch 399/500
# 19/19 [==============================] - 3s 132ms/step - loss: 34.5805 - val_loss: 41.8602
# Epoch 400/500
# 19/19 [==============================] - 2s 132ms/step - loss: 25.7416 - val_loss: 41.6281
# Epoch 401/500
# 19/19 [==============================] - 3s 132ms/step - loss: 32.2571 - val_loss: 41.9509
# Epoch 402/500
# 19/19 [==============================] - 3s 134ms/step - loss: 27.3529 - val_loss: 42.7146
# Epoch 403/500
# 19/19 [==============================] - 4s 187ms/step - loss: 39.1197 - val_loss: 41.9068
# Epoch 404/500
# 19/19 [==============================] - 3s 135ms/step - loss: 36.6760 - val_loss: 44.1339
# Epoch 405/500
# 19/19 [==============================] - 3s 135ms/step - loss: 50.1193 - val_loss: 41.2957
# Epoch 406/500
# 19/19 [==============================] - 4s 196ms/step - loss: 54.1025 - val_loss: 48.0684
# Epoch 407/500
# 19/19 [==============================] - 3s 133ms/step - loss: 65.6671 - val_loss: 46.8227
# Epoch 408/500
# 19/19 [==============================] - 2s 130ms/step - loss: 53.0916 - val_loss: 50.3326
# Epoch 409/500
# 19/19 [==============================] - 4s 196ms/step - loss: 77.9156 - val_loss: 63.1440
# Epoch 410/500
# 19/19 [==============================] - 4s 196ms/step - loss: 46.3999 - val_loss: 59.1375
# Epoch 411/500
# 19/19 [==============================] - 2s 131ms/step - loss: 80.8266 - val_loss: 47.1777
# Epoch 412/500
# 19/19 [==============================] - 3s 133ms/step - loss: 46.8841 - val_loss: 53.9041
# Epoch 413/500
# 19/19 [==============================] - 2s 130ms/step - loss: 41.3135 - val_loss: 48.7091
# Epoch 414/500
# 19/19 [==============================] - 4s 191ms/step - loss: 41.5674 - val_loss: 51.6729
# Epoch 415/500
# 19/19 [==============================] - 3s 135ms/step - loss: 46.5341 - val_loss: 47.9327
# Epoch 416/500
# 19/19 [==============================] - 3s 132ms/step - loss: 26.0304 - val_loss: 46.2797
# Epoch 417/500
# 19/19 [==============================] - 2s 132ms/step - loss: 35.1733 - val_loss: 55.4467
# Epoch 418/500
# 19/19 [==============================] - 3s 133ms/step - loss: 42.6366 - val_loss: 43.0257
# Epoch 419/500
# 19/19 [==============================] - 3s 179ms/step - loss: 29.8858 - val_loss: 43.7969
# Epoch 420/500
# 19/19 [==============================] - 3s 133ms/step - loss: 25.3018 - val_loss: 45.4435
# Epoch 421/500
# 19/19 [==============================] - 2s 131ms/step - loss: 32.9074 - val_loss: 40.9559
# Epoch 422/500
# 19/19 [==============================] - 3s 132ms/step - loss: 25.7509 - val_loss: 43.7275
# Epoch 423/500
# 19/19 [==============================] - 4s 192ms/step - loss: 36.8542 - val_loss: 42.6909
# Epoch 424/500
# 19/19 [==============================] - 2s 132ms/step - loss: 32.3744 - val_loss: 47.5619
# Epoch 425/500
# 19/19 [==============================] - 3s 133ms/step - loss: 47.6778 - val_loss: 44.5559
# Epoch 426/500
# 19/19 [==============================] - 2s 132ms/step - loss: 27.7337 - val_loss: 49.8978
# Epoch 427/500
# 19/19 [==============================] - 4s 202ms/step - loss: 44.5408 - val_loss: 42.4886
# Epoch 428/500
# 19/19 [==============================] - 2s 132ms/step - loss: 47.0491 - val_loss: 56.8567
# Epoch 429/500
# 19/19 [==============================] - 3s 132ms/step - loss: 90.3426 - val_loss: 47.6845
# Epoch 430/500
# 19/19 [==============================] - 3s 138ms/step - loss: 64.7591 - val_loss: 52.4247
# Epoch 431/500
# 19/19 [==============================] - 4s 181ms/step - loss: 102.8358 - val_loss: 57.2128
# Epoch 432/500
# 19/19 [==============================] - 2s 131ms/step - loss: 117.5718 - val_loss: 95.7115
# Epoch 433/500
# 19/19 [==============================] - 3s 133ms/step - loss: 129.5439 - val_loss: 62.3947
# Epoch 434/500
# 19/19 [==============================] - 2s 131ms/step - loss: 86.2152 - val_loss: 62.1307
# Epoch 435/500
# 19/19 [==============================] - 4s 193ms/step - loss: 91.0702 - val_loss: 53.4794
# Epoch 436/500
# 19/19 [==============================] - 3s 134ms/step - loss: 89.4581 - val_loss: 69.3086
# Epoch 437/500
# 19/19 [==============================] - 3s 135ms/step - loss: 129.5282 - val_loss: 93.2009
# Epoch 438/500
# 19/19 [==============================] - 3s 182ms/step - loss: 121.7183 - val_loss: 89.7898
# Epoch 439/500
# 19/19 [==============================] - 3s 135ms/step - loss: 120.1448 - val_loss: 86.6337
# Epoch 440/500
# 19/19 [==============================] - 3s 132ms/step - loss: 143.9622 - val_loss: 120.3582
# Epoch 441/500
# 19/19 [==============================] - 2s 131ms/step - loss: 156.7989 - val_loss: 71.2767
# Epoch 442/500
# 19/19 [==============================] - 4s 188ms/step - loss: 154.6556 - val_loss: 92.0703
# Epoch 443/500
# 19/19 [==============================] - 2s 129ms/step - loss: 103.7274 - val_loss: 109.2558
# Epoch 444/500
# 19/19 [==============================] - 2s 132ms/step - loss: 77.0428 - val_loss: 75.1737
# Epoch 445/500
# 19/19 [==============================] - 3s 132ms/step - loss: 50.4089 - val_loss: 47.7401
# Epoch 446/500
# 19/19 [==============================] - 4s 194ms/step - loss: 47.7012 - val_loss: 60.2653
# Epoch 447/500
# 19/19 [==============================] - 3s 136ms/step - loss: 80.0990 - val_loss: 51.8852
# Epoch 448/500
# 19/19 [==============================] - 3s 134ms/step - loss: 46.5646 - val_loss: 53.6315
# Epoch 449/500
# 19/19 [==============================] - 3s 134ms/step - loss: 58.0974 - val_loss: 46.0261
# Epoch 450/500
# 19/19 [==============================] - 4s 195ms/step - loss: 41.2870 - val_loss: 48.1774
# Epoch 451/500
# 19/19 [==============================] - 2s 132ms/step - loss: 53.8041 - val_loss: 52.8301
# Epoch 452/500
# 19/19 [==============================] - 3s 134ms/step - loss: 52.1822 - val_loss: 43.4897
# Epoch 453/500
# 19/19 [==============================] - 2s 130ms/step - loss: 59.0094 - val_loss: 57.1779
# Epoch 454/500
# 19/19 [==============================] - 4s 200ms/step - loss: 61.4631 - val_loss: 48.8120
# Epoch 455/500
# 19/19 [==============================] - 3s 135ms/step - loss: 66.3772 - val_loss: 73.3679
# Epoch 456/500
# 19/19 [==============================] - 3s 134ms/step - loss: 56.9302 - val_loss: 54.7239
# Epoch 457/500
# 19/19 [==============================] - 4s 195ms/step - loss: 49.0336 - val_loss: 44.7867
# Epoch 458/500
# 19/19 [==============================] - 3s 133ms/step - loss: 44.5757 - val_loss: 46.9886
# Epoch 459/500
# 19/19 [==============================] - 2s 132ms/step - loss: 43.6621 - val_loss: 44.0960
# Epoch 460/500
# 19/19 [==============================] - 3s 134ms/step - loss: 36.8897 - val_loss: 41.2597
# Epoch 461/500
# 19/19 [==============================] - 4s 201ms/step - loss: 32.0818 - val_loss: 41.4853
# Epoch 462/500
# 19/19 [==============================] - 3s 137ms/step - loss: 24.3723 - val_loss: 44.8027
# Epoch 463/500
# 19/19 [==============================] - 3s 132ms/step - loss: 30.0930 - val_loss: 42.9432
# Epoch 464/500
# 19/19 [==============================] - 3s 133ms/step - loss: 28.0380 - val_loss: 44.0588
# Epoch 465/500
# 19/19 [==============================] - 3s 184ms/step - loss: 29.2578 - val_loss: 42.8101
# Epoch 466/500
# 19/19 [==============================] - 3s 136ms/step - loss: 23.8903 - val_loss: 44.6968
# Epoch 467/500
# 19/19 [==============================] - 3s 136ms/step - loss: 26.1369 - val_loss: 43.5038
# Epoch 468/500
# 19/19 [==============================] - 3s 136ms/step - loss: 23.1546 - val_loss: 45.7926
# Epoch 469/500
# 19/19 [==============================] - 3s 133ms/step - loss: 24.5925 - val_loss: 43.1632
# Epoch 470/500
# 19/19 [==============================] - 3s 171ms/step - loss: 21.2646 - val_loss: 45.0783
# Epoch 471/500
# 19/19 [==============================] - 2s 132ms/step - loss: 21.3168 - val_loss: 41.1078
# Epoch 472/500
# 19/19 [==============================] - 3s 134ms/step - loss: 18.6677 - val_loss: 43.1901
# Epoch 473/500
# 19/19 [==============================] - 3s 134ms/step - loss: 19.6444 - val_loss: 39.9498
# Epoch 474/500
# 19/19 [==============================] - 4s 196ms/step - loss: 18.6760 - val_loss: 42.1072
# Epoch 475/500
# 19/19 [==============================] - 3s 133ms/step - loss: 21.2900 - val_loss: 40.3200
# Epoch 476/500
# 19/19 [==============================] - 3s 133ms/step - loss: 20.2607 - val_loss: 42.2764
# Epoch 477/500
# 19/19 [==============================] - 3s 135ms/step - loss: 23.4198 - val_loss: 41.4291
# Epoch 478/500
# 19/19 [==============================] - 4s 189ms/step - loss: 20.6420 - val_loss: 41.3706
# Epoch 479/500
# 19/19 [==============================] - 3s 133ms/step - loss: 23.3266 - val_loss: 41.2506
# Epoch 480/500
# 19/19 [==============================] - 3s 134ms/step - loss: 21.3567 - val_loss: 42.1471
# Epoch 481/500
# 19/19 [==============================] - 2s 131ms/step - loss: 25.4661 - val_loss: 41.5283
# Epoch 482/500
# 19/19 [==============================] - 4s 186ms/step - loss: 22.2266 - val_loss: 43.1835
# Epoch 483/500
# 19/19 [==============================] - 3s 141ms/step - loss: 32.1980 - val_loss: 42.7719
# Epoch 484/500
# 19/19 [==============================] - 3s 166ms/step - loss: 25.4508 - val_loss: 45.5483
# Epoch 485/500
# 19/19 [==============================] - 4s 211ms/step - loss: 38.7518 - val_loss: 41.5416
# Epoch 486/500
# 19/19 [==============================] - 3s 132ms/step - loss: 26.7781 - val_loss: 46.2011
# Epoch 487/500
# 19/19 [==============================] - 2s 132ms/step - loss: 36.9917 - val_loss: 46.0410
# Epoch 488/500
# 19/19 [==============================] - 4s 197ms/step - loss: 25.6468 - val_loss: 47.2528
# Epoch 489/500
# 19/19 [==============================] - 3s 133ms/step - loss: 28.5035 - val_loss: 42.6842
# Epoch 490/500
# 19/19 [==============================] - 3s 133ms/step - loss: 22.0922 - val_loss: 43.4868
# Epoch 491/500
# 19/19 [==============================] - 3s 133ms/step - loss: 24.0060 - val_loss: 41.6246
# Epoch 492/500
# 19/19 [==============================] - 4s 193ms/step - loss: 17.1720 - val_loss: 39.6404
# Epoch 493/500
# 19/19 [==============================] - 2s 129ms/step - loss: 16.5797 - val_loss: 41.0377
# Epoch 494/500
# 19/19 [==============================] - 2s 132ms/step - loss: 15.2090 - val_loss: 39.8717
# Epoch 495/500
# 19/19 [==============================] - 3s 133ms/step - loss: 15.2768 - val_loss: 40.6880
# Epoch 496/500
# 19/19 [==============================] - 3s 183ms/step - loss: 15.1978 - val_loss: 39.6792
# Epoch 497/500
# 19/19 [==============================] - 3s 138ms/step - loss: 15.7836 - val_loss: 41.6194
# Epoch 498/500
# 19/19 [==============================] - 3s 133ms/step - loss: 15.4937 - val_loss: 41.5485
# Epoch 499/500
# 19/19 [==============================] - 3s 134ms/step - loss: 17.2522 - val_loss: 41.1259
# Epoch 500/500
# 19/19 [==============================] - 3s 136ms/step - loss: 18.0162 - val_loss: 40.8410

# %% [markdown]
# ## **7. Đánh giá và trực quan hóa**

# %%
def mae(y_true, y_pred):
    mae = np.mean(np.abs((y_true - y_pred)))

    return mae

def mse(y_true, y_pred):
    mse = np.mean((y_true - y_pred) ** 2)

    return mse

def rmse(y_true, y_pred):
    rmse = np.sqrt(np.mean((y_true-y_pred)**2))

    return rmse

def mape(y_true, y_pred):
    mape = np.mean(np.abs((y_true-y_pred) / y_true)) * 100

    return mape

# %%
y_test_pred = model.predict(X_test, verbose=0)
print(f'RMSE: {rmse(y_test, y_test_pred)}')
print(f'MAPE: {mape(y_test, y_test_pred)}')
print(f'MSE: {mse(y_test, y_test_pred)}')
print(f'MAE: {mae(y_test, y_test_pred)}')
# Out:
# RMSE: 5.572335944931852
# MAPE: 2.018114312479236
# MSE: 31.05092788317955
# MAE: 4.355997792883213

# %%
train_loss = history.history['loss']# Đọc thông tin loss trên tập train
val_loss = history.history['val_loss'] # Đọc thông tin loss trên tập val

plt.figure(figsize=(10, 5)) # Cài đặt kích thước khung ảnh

plt.subplot(1, 2, 1) # Khởi tạo khung ảnh cho training loss
plt.xlabel('Epochs') # Hiển thị tên trục hoành là 'Epochs'
plt.ylabel('Loss') # Hiển thị tên trục tung là 'Loss'
plt.title('Training loss') # Hiển thị title của khung ảnh hiện tại là 'Training Loss'
plt.plot(train_loss, color='green') # Vẽ đường giá trị loss trên tập train qua từng epoch (đường vẽ màu đỏ)

plt.subplot(1, 2, 2) # Khởi tạo khung ảnh cho val loss
plt.xlabel('Epochs') # Hiển thị tên trục hoành là 'Epochs'
plt.ylabel('Loss') # Hiển thị tên trục tung là 'Loss'
plt.title('Validation loss') # Hiển thị title của khung ảnh hiện tại là 'Validation loss'
plt.plot(val_loss, color='orange') # Vẽ đường giá trị loss trên tập val qua từng epoch (đường vẽ màu đỏ)

plt.show() # Hiển thị 2 khung ảnh nhỏ

# %%
def plot_difference(y, pred):
    plt.figure(figsize=(20, 6))
    times = range(len(y))
    y_to_plot = y.flatten()
    pred_to_plot = pred.flatten()

    plt.plot(times, y_to_plot, color='steelblue', marker='o', label='True value')
    plt.plot(times, pred_to_plot, color='orangered', marker='X', label='Prediction')

    plt.title('Adj Closing Price per day')
    plt.xlabel('Date')
    plt.ylabel('Adj Close Price')
    plt.legend()
    plt.show()

plot_difference(y_test[:300], model.predict(X_test[:300], verbose=0))
